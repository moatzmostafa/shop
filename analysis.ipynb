# %%
import seaborn as sns
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
import numpy as np
import sklearn.metrics as mc
import scipy
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\moatz\Downloads\casho.csv")
df
# Out:
#                   branch name  panuary  feb average  march average  \
# 0             صيدلية ليمون 04  15000.0      14873.0        16036.0
# 1             صيدلية ليمون 10  11100.0      11200.0        11200.0
# 2             صيدلية ليمون 11      NaN          NaN            NaN
# 3             صيدلية ليمون 13   8583.0       7500.0         7866.0
# 4             صيدلية ليمون 14   4050.0       3662.0         3563.0
# 5             صيدلية ليمون 16   2113.0       2244.0         2081.0
# 6             صيدلية ليمون 17   4069.0       4062.0         3693.0
# 7             صيدلية ليمون 20   8100.0       8011.0         8926.0
# 8             صيدلية ليمون 25      NaN          NaN            NaN
# 9           صيدلية ليمون إيفا  11296.0      11508.0        10740.0
# 10    صيدلية ليمون السليمانية   6977.0       6214.0         5994.0
# 11  صيدلية ليمون حي ام الحمام   9876.0       9954.0         9228.0
# 12          صيدلية الحزيمي 01  10192.0       9490.0        11545.0
# ...

# %%
df.columns= df.columns.str.capitalize()

# %%
df
# Out:
#                   Branch name  Panuary  Feb average  March average  \
# 0             صيدلية ليمون 04  15000.0      14873.0        16036.0
# 1             صيدلية ليمون 10  11100.0      11200.0        11200.0
# 2             صيدلية ليمون 11      NaN          NaN            NaN
# 3             صيدلية ليمون 13   8583.0       7500.0         7866.0
# 4             صيدلية ليمون 14   4050.0       3662.0         3563.0
# 5             صيدلية ليمون 16   2113.0       2244.0         2081.0
# 6             صيدلية ليمون 17   4069.0       4062.0         3693.0
# 7             صيدلية ليمون 20   8100.0       8011.0         8926.0
# 8             صيدلية ليمون 25      NaN          NaN            NaN
# 9           صيدلية ليمون إيفا  11296.0      11508.0        10740.0
# 10    صيدلية ليمون السليمانية   6977.0       6214.0         5994.0
# 11  صيدلية ليمون حي ام الحمام   9876.0       9954.0         9228.0
# 12          صيدلية الحزيمي 01  10192.0       9490.0        11545.0
# ...

# %%
df.sort_values(by='Panuary',ascending=False)
# Out:
#                   Branch name  Panuary  Feb average  March average  \
# 13          صيدلية الحزيمي 02  21130.0      20671.0        23577.0
# 0             صيدلية ليمون 04  15000.0      14873.0        16036.0
# 9           صيدلية ليمون إيفا  11296.0      11508.0        10740.0
# 1             صيدلية ليمون 10  11100.0      11200.0        11200.0
# 12          صيدلية الحزيمي 01  10192.0       9490.0        11545.0
# 11  صيدلية ليمون حي ام الحمام   9876.0       9954.0         9228.0
# 19              ليمون 64 طنجة   8811.0       8434.0         8378.0
# 3             صيدلية ليمون 13   8583.0       7500.0         7866.0
# 7             صيدلية ليمون 20   8100.0       8011.0         8926.0
# 10    صيدلية ليمون السليمانية   6977.0       6214.0         5994.0
# 22            ليمون 133 القدس   6764.0       5778.0         5804.0
# 17      صيدلية ليمون ابن حكيم   6743.0       6382.0         6889.0
# 21        ليمون 43 الفارابى 2   5931.0       5308.0         5086.0
# ...

# %%
sns.heatmap(df.corr(exclude='string'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.heatmap(df.corr(exclude='string'))
#
# TypeError: DataFrame.corr() got an unexpected keyword argument 'exclude'

# %%
numeric_df = df.select_dtypes(include=[float, int])

# %%
corr_matrix = numeric_df.corr()

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
df.dropna(inplace=True)

# %%
df['Total sales']= df['Panuary'] + df['Feb average'] + df['April average']+ df['March average']

# %%
df
# Out:
#                   Branch name  Panuary  Feb average  March average  \
# 0             صيدلية ليمون 04  15000.0      14873.0        16036.0
# 1             صيدلية ليمون 10  11100.0      11200.0        11200.0
# 3             صيدلية ليمون 13   8583.0       7500.0         7866.0
# 4             صيدلية ليمون 14   4050.0       3662.0         3563.0
# 5             صيدلية ليمون 16   2113.0       2244.0         2081.0
# 6             صيدلية ليمون 17   4069.0       4062.0         3693.0
# 7             صيدلية ليمون 20   8100.0       8011.0         8926.0
# 9           صيدلية ليمون إيفا  11296.0      11508.0        10740.0
# 10    صيدلية ليمون السليمانية   6977.0       6214.0         5994.0
# 11  صيدلية ليمون حي ام الحمام   9876.0       9954.0         9228.0
# 12          صيدلية الحزيمي 01  10192.0       9490.0        11545.0
# 13          صيدلية الحزيمي 02  21130.0      20671.0        23577.0
# 14            صيدلية ليمون 42   2528.0       2487.0         2445.0
# ...

# %%
sns.kdeplot(data=df,x='Total sales')
# Out:
# <Axes: xlabel='Total sales', ylabel='Density'>

# %%
sns.displot(data=df,x='Total sales')
# Out:
# C:\Users\moatz\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lineplot(data=df,x='Panuary',y='Total sales')
# Out:
# <Axes: xlabel='Panuary', ylabel='Total sales'>

# %%
sns.scatterplot(data=df,x='Panuary',y='Total sales')
# Out:
# <Axes: xlabel='Panuary', ylabel='Total sales'>

# %%
df
# Out:
#                   Branch name  Panuary  Feb average  March average  \
# 0             صيدلية ليمون 04  15000.0      14873.0        16036.0
# 1             صيدلية ليمون 10  11100.0      11200.0        11200.0
# 3             صيدلية ليمون 13   8583.0       7500.0         7866.0
# 4             صيدلية ليمون 14   4050.0       3662.0         3563.0
# 5             صيدلية ليمون 16   2113.0       2244.0         2081.0
# 6             صيدلية ليمون 17   4069.0       4062.0         3693.0
# 7             صيدلية ليمون 20   8100.0       8011.0         8926.0
# 9           صيدلية ليمون إيفا  11296.0      11508.0        10740.0
# 10    صيدلية ليمون السليمانية   6977.0       6214.0         5994.0
# 11  صيدلية ليمون حي ام الحمام   9876.0       9954.0         9228.0
# 12          صيدلية الحزيمي 01  10192.0       9490.0        11545.0
# 13          صيدلية الحزيمي 02  21130.0      20671.0        23577.0
# 14            صيدلية ليمون 42   2528.0       2487.0         2445.0
# ...

# %%
df = pd.read_excel(r"C:\Users\moatz\Desktop\opaaaaaa222.xlsx")
df
# Out:
#    Unnamed: 0    Target     Sales  daily average  av no of buyers  \
# 0  2023-01-01  312209.0  273798.0         8832.0             59.0
# 1  2023-01-02  277088.0  222243.0         7937.0             52.0
# 2  2023-01-03  242530.0  186390.0         6013.0             48.0
# 3  2023-01-04  195434.0  174518.0         6018.0             64.0
# 4  2023-01-05  291576.0  296962.0         9571.0             77.0
# 5  2023-01-06  273093.0  221078.0         7623.0             68.0
# 6  2023-01-07  382704.0  252779.0         8165.0             56.0
# 7  2023-01-08  211065.0  227088.0         7325.0             50.0
# 8  2023-01-09  167809.0  155153.0         5172.0             57.0
# 9  2023-01-10  168488.0  161669.0         5215.0             67.0
# 10 2023-01-11  230160.0  201571.0         6719.0             62.0
# 11 2023-01-12  208687.0  199644.0         6440.0             69.0
# 12 2024-01-01  151949.0  144579.0         4309.0             71.0
# ...

# %%
df.rename(columns={'Unnamed: 0': 'month'}, inplace=True)

# %%
df
# Out:
#         month    Target     Sales  daily average  av no of buyers  \
# 0  2023-01-01  312209.0  273798.0         8832.0             59.0
# 1  2023-01-02  277088.0  222243.0         7937.0             52.0
# 2  2023-01-03  242530.0  186390.0         6013.0             48.0
# 3  2023-01-04  195434.0  174518.0         6018.0             64.0
# 4  2023-01-05  291576.0  296962.0         9571.0             77.0
# 5  2023-01-06  273093.0  221078.0         7623.0             68.0
# 6  2023-01-07  382704.0  252779.0         8165.0             56.0
# 7  2023-01-08  211065.0  227088.0         7325.0             50.0
# 8  2023-01-09  167809.0  155153.0         5172.0             57.0
# 9  2023-01-10  168488.0  161669.0         5215.0             67.0
# 10 2023-01-11  230160.0  201571.0         6719.0             62.0
# 11 2023-01-12  208687.0  199644.0         6440.0             69.0
# 12 2024-01-01  151949.0  144579.0         4309.0             71.0
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         month    Target     Sales  daily average  av no of buyers  \
# 0  2023-01-01  312209.0  273798.0         8832.0             59.0
# 1  2023-01-02  277088.0  222243.0         7937.0             52.0
# 2  2023-01-03  242530.0  186390.0         6013.0             48.0
# 3  2023-01-04  195434.0  174518.0         6018.0             64.0
# 4  2023-01-05  291576.0  296962.0         9571.0             77.0
# 5  2023-01-06  273093.0  221078.0         7623.0             68.0
# 6  2023-01-07  382704.0  252779.0         8165.0             56.0
# 7  2023-01-08  211065.0  227088.0         7325.0             50.0
# 8  2023-01-09  167809.0  155153.0         5172.0             57.0
# 9  2023-01-10  168488.0  161669.0         5215.0             67.0
# 10 2023-01-11  230160.0  201571.0         6719.0             62.0
# 11 2023-01-12  208687.0  199644.0         6440.0             69.0
# 12 2024-01-01  151949.0  144579.0         4309.0             71.0
# ...

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
df
# Out:
#         month    Target     Sales  daily average  av no of buyers  \
# 0  2023-01-01  312209.0  273798.0         8832.0             59.0
# 1  2023-01-02  277088.0  222243.0         7937.0             52.0
# 2  2023-01-03  242530.0  186390.0         6013.0             48.0
# 3  2023-01-04  195434.0  174518.0         6018.0             64.0
# 4  2023-01-05  291576.0  296962.0         9571.0             77.0
# 5  2023-01-06  273093.0  221078.0         7623.0             68.0
# 6  2023-01-07  382704.0  252779.0         8165.0             56.0
# 7  2023-01-08  211065.0  227088.0         7325.0             50.0
# 8  2023-01-09  167809.0  155153.0         5172.0             57.0
# 9  2023-01-10  168488.0  161669.0         5215.0             67.0
# 10 2023-01-11  230160.0  201571.0         6719.0             62.0
# 11 2023-01-12  208687.0  199644.0         6440.0             69.0
# 12 2024-01-01  151949.0  144579.0         4309.0             71.0
# ...

# %%
x = df[['daily average']]
x
# Out:
#     daily average
# 0          8832.0
# 1          7937.0
# 2          6013.0
# 3          6018.0
# 4          9571.0
# 5          7623.0
# 6          8165.0
# 7          7325.0
# 8          5172.0
# 9          5215.0
# 10         6719.0
# 11         6440.0
# 12         4309.0
# 13         3870.0

# %%
y = df[['Sales']]
y
# Out:
#        Sales
# 0   273798.0
# 1   222243.0
# 2   186390.0
# 3   174518.0
# 4   296962.0
# 5   221078.0
# 6   252779.0
# 7   227088.0
# 8   155153.0
# 9   161669.0
# 10  201571.0
# 11  199644.0
# 12  144579.0
# 13  108350.0

# %%
reg = linear_model.LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.predict([[3870]])
# Out:
# C:\Users\moatz\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[117183.42360674]])

# %%
reg.predict([[40000]])
# Out:
# array([53763.92265641])

# %%
import tkinter as tk

# %%
import tkinter as tk

# Create the main window
root = tk.Tk()

# Set the title
root.title("a7a")

# Set the window size
root.geometry("400x600")

# Create a label
label = tk.Label(root, text="moatz mostafa")
label.pack(pady=20)

# Run the application
root.mainloop()

# %%
df
# Out:
#         month    Target     Sales  daily average  av no of buyers  \
# 0  2023-01-01  312209.0  273798.0         8832.0             59.0
# 1  2023-01-02  277088.0  222243.0         7937.0             52.0
# 2  2023-01-03  242530.0  186390.0         6013.0             48.0
# 3  2023-01-04  195434.0  174518.0         6018.0             64.0
# 4  2023-01-05  291576.0  296962.0         9571.0             77.0
# 5  2023-01-06  273093.0  221078.0         7623.0             68.0
# 6  2023-01-07  382704.0  252779.0         8165.0             56.0
# 7  2023-01-08  211065.0  227088.0         7325.0             50.0
# 8  2023-01-09  167809.0  155153.0         5172.0             57.0
# 9  2023-01-10  168488.0  161669.0         5215.0             67.0
# 10 2023-01-11  230160.0  201571.0         6719.0             62.0
# 11 2023-01-12  208687.0  199644.0         6440.0             69.0
# 12 2024-01-01  151949.0  144579.0         4309.0             71.0
# ...

# %%
print(df.groupby('Sales'))

# %%
print(df.groupby('Sales').groups)
# Out:
# {108350.0: [13], 144579.0: [12], 155153.0: [8], 161669.0: [9], 174518.0: [3], 186390.0: [2], 199644.0: [11], 201571.0: [10], 221078.0: [5], 222243.0: [1], 227088.0: [7], 252779.0: [6], 273798.0: [0], 296962.0: [4]}

# %%
g = df.groupby("Sales")
g

# %%
g.min()
# Out:
#               month    Target  daily average  av no of buyers  \
# Sales
# 108350.0 2024-01-02  132764.0         3870.0             63.0
# 144579.0 2024-01-01  151949.0         4309.0             71.0
# 155153.0 2023-01-09  167809.0         5172.0             57.0
# 161669.0 2023-01-10  168488.0         5215.0             67.0
# 174518.0 2023-01-04  195434.0         6018.0             64.0
# 186390.0 2023-01-03  242530.0         6013.0             48.0
# 199644.0 2023-01-12  208687.0         6440.0             69.0
# 201571.0 2023-01-11  230160.0         6719.0             62.0
# 221078.0 2023-01-06  273093.0         7623.0             68.0
# 222243.0 2023-01-02  277088.0         7937.0             52.0
# 227088.0 2023-01-08  211065.0         7325.0             50.0
# 252779.0 2023-01-07  382704.0         8165.0             56.0
# 273798.0 2023-01-01  312209.0         8832.0             59.0
# 296962.0 2023-01-05  291576.0         9571.0             77.0
#
# ...

# %%
g.plot()
# Out:
# Sales
# 108350.0    Axes(0.125,0.11;0.775x0.77)
# 144579.0    Axes(0.125,0.11;0.775x0.77)
# 155153.0    Axes(0.125,0.11;0.775x0.77)
# 161669.0    Axes(0.125,0.11;0.775x0.77)
# 174518.0    Axes(0.125,0.11;0.775x0.77)
# 186390.0    Axes(0.125,0.11;0.775x0.77)
# 199644.0    Axes(0.125,0.11;0.775x0.77)
# 201571.0    Axes(0.125,0.11;0.775x0.77)
# 221078.0    Axes(0.125,0.11;0.775x0.77)
# 222243.0    Axes(0.125,0.11;0.775x0.77)
# 227088.0    Axes(0.125,0.11;0.775x0.77)
# 252779.0    Axes(0.125,0.11;0.775x0.77)
# 273798.0    Axes(0.125,0.11;0.775x0.77)
# 296962.0    Axes(0.125,0.11;0.775x0.77)
# dtype: object
